# %%
import array as myarray

# %%
arr = myarray.array('i',[55,66,77])
arr1 = myarray.array('d',[1.1,1.2,1.3,1.4,1.5])
arr2 = myarray.array('u',['v','e','d','a','n','t'])

# %%
for i in range(0,len(arr)):
    print(i)
# Out:
# 0
# 1
# 2

# %%
print(len(arr))
print(len(arr1))
print(len(arr2))
# Out:
# 3
# 5
# 6

# %%
print(arr)
print(arr1)
print(arr2)
# Out:
# array('i', [1, 2, 3])
# array('d', [1.1, 1.2, 1.3, 1.4, 1.5])
# array('u', 'vedant')

# %%
print(arr.typecode)
print(arr1.typecode)
print(arr2.typecode)
# Out:
# i
# d
# u
